# %% [markdown]
# # Pinnacle Odds Scraper – Local EDA

# %%
# Run this once to install ChromeDriver for local use (required for OddsScraper outside Lambda)
# %pip install -q webdriver-manager selenium beautifulsoup4
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
1==1
# Out:
# True

# %%
from scraper import OddsScraper

scraper = OddsScraper()
# Out:
# 05-Mar-26 09:34:02 INFO 20208 --- WDM                  log() : ====== WebDriver manager ======
# No running driver found
# 05-Mar-26 09:34:02 INFO 20208 --- WDM                  log() : Get LATEST chromedriver version for google-chrome
# 05-Mar-26 09:34:02 INFO 20208 --- WDM                  log() : Get LATEST chromedriver version for google-chrome
# 05-Mar-26 09:34:02 INFO 20208 --- WDM                  log() : Driver [/Users/pietervantol/.wdm/drivers/chromedriver/mac64/145.0.7632.117/chromedriver-mac-arm64/chromedriver] found in cache

# %%
# Example: fetch super league odds (then close the browser when done)
# odds = scraper.get_odds(sport1='Basketball', country1='USA', league1='NBA')
# print(odds)
# scraper.close_connection()
